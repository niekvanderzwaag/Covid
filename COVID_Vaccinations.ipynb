# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12,6]
sns.set_theme(style='darkgrid')

# %%
covid = pd.read_csv('owid-covid-data.csv')

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149880 entries, 0 to 149879
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    149880 non-null  object
#  1   continent                                   140834 non-null  object
#  2   location                                    149880 non-null  object
#  3   date                                        149880 non-null  object
#  4   total_cases                                 147259 non-null  float64
#  5   new_cases                                   147253 non-null  float64
#  6   new_cases_smoothed                          146108 non-null  float64
#  7   total_deaths                                130199 non-null  float64
#  8   new_deaths                                  130394 non-null  float64
#  9   new_deaths_smoothed                         146108 non-null  float64
#  10  total_cases_per_million                     146571 non-null  float64
#  11  new_cases_per_million                       146565 non-null  float64
#  12  new_cases_smoothed_per_million              145425 non-null  float64
#  13  total_deaths_per_million                    129524 non-null  float64
#  14  new_deaths_per_million                      129719 non-null  float64
#  15  new_deaths_smoothed_per_million             145425 non-null  float64
#  16  reproduction_rate                           112750 non-null  float64
#  17  icu_patients                                17049 non-null   float64
#  18  icu_patients_per_million                    17049 non-null   float64
#  19  hosp_patients                               20170 non-null   float64
#  20  hosp_patients_per_million                   20170 non-null   float64
#  21  weekly_icu_admissions                       3875 non-null    float64
#  22  weekly_icu_admissions_per_million           3875 non-null    float64
#  23  weekly_hosp_admissions                      7889 non-null    float64
#  24  weekly_hosp_admissions_per_million          7889 non-null    float64
#  25  new_tests                                   59597 non-null   float64
#  26  total_tests                                 59774 non-null   float64
#  27  total_tests_per_thousand                    59774 non-null   float64
#  28  new_tests_per_thousand                      59597 non-null   float64
#  29  new_tests_smoothed                          72648 non-null   float64
#  30  new_tests_smoothed_per_thousand             71962 non-null   float64
#  31  positive_rate                               67786 non-null   float64
#  32  tests_per_case                              67124 non-null   float64
#  33  tests_units                                 74093 non-null   object
#  34  total_vaccinations                          37771 non-null   float64
#  35  people_vaccinated                           36293 non-null   float64
#  36  people_fully_vaccinated                     33513 non-null   float64
#  37  total_boosters                              11068 non-null   float64
#  38  new_vaccinations                            31291 non-null   float64
#  39  new_vaccinations_smoothed                   68881 non-null   float64
#  40  total_vaccinations_per_hundred              37771 non-null   float64
#  41  people_vaccinated_per_hundred               36293 non-null   float64
#  42  people_fully_vaccinated_per_hundred         33513 non-null   float64
#  43  total_boosters_per_hundred                  11068 non-null   float64
#  44  new_vaccinations_smoothed_per_million       68881 non-null   float64
#  45  new_people_vaccinated_smoothed              67731 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  67731 non-null   float64
#  47  stringency_index                            117312 non-null  float64
#  48  population                                  148875 non-null  float64
#  49  population_density                          133423 non-null  float64
#  50  median_age                                  124520 non-null  float64
#  51  aged_65_older                               123166 non-null  float64
#  52  aged_70_older                               123851 non-null  float64
#  53  gdp_per_capita                              124913 non-null  float64
#  54  extreme_poverty                             82465 non-null   float64
#  55  cardiovasc_death_rate                       123536 non-null  float64
#  56  diabetes_prevalence                         129863 non-null  float64
#  57  female_smokers                              95694 non-null   float64
#  58  male_smokers                                94314 non-null   float64
#  59  handwashing_facilities                      61869 non-null   float64
#  60  hospital_beds_per_thousand                  111622 non-null  float64
#  61  life_expectancy                             139878 non-null  float64
#  62  human_development_index                     123013 non-null  float64
#  63  excess_mortality_cumulative_absolute        5125 non-null    float64
#  64  excess_mortality_cumulative                 5125 non-null    float64
#  65  excess_mortality                            5125 non-null    float64
#  66  excess_mortality_cumulative_per_million     5125 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 76.6+ MB

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
confirmed = covid[['iso_code','continent','location','date',]]

# %%
nl = covid[covid['iso_code']=='NLD']

# %%
sns.lineplot(data=nl, x='date', y='total_cases')
sns.lineplot(data=nl, x='date', y='people_vaccinated');
